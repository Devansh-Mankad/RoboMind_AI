# %% [markdown]
# # Dock Contention Search Benchmark
# This notebook compares MiniMax, Alpha-Beta and Alpha-Beta with iterative deepening for depths 2 to 6.

# %%
from dock_game import chart
rows=chart()
for row in rows: print(row)

# %% [markdown]
# The node counts show how pruning changes the amount of search work. Iterative deepening also records a decision time at every depth in the search class.
